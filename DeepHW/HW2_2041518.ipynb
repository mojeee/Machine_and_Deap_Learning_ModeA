# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---

# %% [markdown]
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well known problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.  https://keras.io/

# %% [markdown]
# ##Exercise 2.1: Text Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layers Neural Network to perfrom classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import tensorflow_datasets as tfds
import time

import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)
# os.environ['TF_DETERMINISTIC_OPS']='1'

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Tensorflow Dataset. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes from a larger news corups. The total number of training samples is 120,000 and testing 7,600. Each class contains 30,000 training samples and 1,900 testing samples. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.
#
# We will split the training set into two 90%-10% splits in order to have a validation set.

# %%
### NOTE ### 
# running this cell might yield download-related errors.
# just repeating the execution a couple of times should solve the error.

train_ds, valid_ds, test_ds = tfds.load('ag_news_subset',
                                        as_supervised=True, # return a set of (text, label) tuples 
                                        split=['train[:90%]', 'train[-10%:]', 'test'],
                                        batch_size=-1)  
                                        # ^ using batch_size=-1 returns Tensors instead of Dataset objects
# Out:
# Downloading and preparing dataset ag_news_subset/1.0.0 (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete6ZNNIL/ag_news_subset-train.tfrecord
#   0%|          | 0/120000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete6ZNNIL/ag_news_subset-test.tfrecord
#   0%|          | 0/7600 [00:00<?, ? examples/s]
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.

# %%
# Tensors have two elements, data and labels; let's split them
# so we can transform the data
X_train, y_train = train_ds
X_valid, y_valid = valid_ds
X_test, y_test = test_ds

# %% [markdown]
# The AG News Subset dataset consists in news articles, each one composed by a sequence of words. In order to encode each article in a single tensor with a fixed number of elements, we will use multi-hot encoding. For testing purposes, we will only consider the first 10,000  most common words. Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
num_words = 1000
vectorize_layer = tf.keras.layers.TextVectorization(
 max_tokens=num_words,
 standardize="lower_and_strip_punctuation",
 split="whitespace",
 output_mode='multi_hot',
 pad_to_max_tokens=True)

vectorize_layer.adapt(X_train)

# %%
X_train = vectorize_layer(X_train)
X_valid = vectorize_layer(X_valid)
X_test  = vectorize_layer(X_test)

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (`keras.models.Sequential`) and add four layers to it by calling its `add()` method:
#
#
# *   a input layer (`tf.keras.Input`) that is the first layer in your model. With this layer you should specify the `input_shape` argument, leaving out the batch size: `(num_words,)`;
# *  a Dense layer (`keras.layers.Dense`) with 16 neurons, and the "relu" activation function;
# * another Dense layer with 16 neurons, also with the "relu" activation function;
# * a final Dense layer with 4 output neurons, and with the "softmax" activation (since we considering a classification task with four classes).

# %%
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# %% [markdown]
# Call the model's `summary()` method to check if the model has been built correctly. Also, try using `keras.utils.plot_model()` to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                16016
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 16,356
# Trainable params: 16,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (`None`), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# Instaed of using `add()` method it is also possibile to define the model using the following syntax

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(4, activation="softmax")
])
model.summary()
keras.utils.plot_model(model, "my_model.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                16016
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 16,356
# Trainable params: 16,356
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its `compile()` method to specify the loss function and the optimizer to use.
#
# Since the model performs a classification task, and we have labels encoded as integers, we use the sparse categorical cross-entropy loss. As optimizer we use Adam.
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify `metrics=["accuracy"]`.

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its `fit()` method, passing to it the input features (`X_train`) and the target classes (`y_train`). Set the number of epochs to 20.
# In order to validate our model we will also pass the validation data by setting `validation_data=(X_valid, y_valid)`. Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the `fit()` method will return a `History` object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.8503 - accuracy: 0.6761 - val_loss: 0.5107 - val_accuracy: 0.8314
# Epoch 2/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4583 - accuracy: 0.8449 - val_loss: 0.4452 - val_accuracy: 0.8475
# Epoch 3/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4222 - accuracy: 0.8546 - val_loss: 0.4318 - val_accuracy: 0.8507
# Epoch 4/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4089 - accuracy: 0.8573 - val_loss: 0.4241 - val_accuracy: 0.8509
# Epoch 5/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4012 - accuracy: 0.8590 - val_loss: 0.4210 - val_accuracy: 0.8525
# Epoch 6/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3959 - accuracy: 0.8601 - val_loss: 0.4175 - val_accuracy: 0.8531
# Epoch 7/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3917 - accuracy: 0.8615 - val_loss: 0.4149 - val_accuracy: 0.8535
# Epoch 8/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3882 - accuracy: 0.8617 - val_loss: 0.4132 - val_accuracy: 0.8550
# Epoch 9/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3851 - accuracy: 0.8627 - val_loss: 0.4109 - val_accuracy: 0.8540
# Epoch 10/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3825 - accuracy: 0.8629 - val_loss: 0.4096 - val_accuracy: 0.8534
# Epoch 11/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3799 - accuracy: 0.8637 - val_loss: 0.4081 - val_accuracy: 0.8539
# Epoch 12/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3775 - accuracy: 0.8638 - val_loss: 0.4064 - val_accuracy: 0.8543
# Epoch 13/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3753 - accuracy: 0.8645 - val_loss: 0.4051 - val_accuracy: 0.8538
# Epoch 14/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3731 - accuracy: 0.8649 - val_loss: 0.4053 - val_accuracy: 0.8543
# Epoch 15/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3709 - accuracy: 0.8660 - val_loss: 0.4035 - val_accuracy: 0.8553
# Epoch 16/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3689 - accuracy: 0.8661 - val_loss: 0.4027 - val_accuracy: 0.8553
# Epoch 17/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3669 - accuracy: 0.8668 - val_loss: 0.4011 - val_accuracy: 0.8565
# Epoch 18/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3649 - accuracy: 0.8672 - val_loss: 0.4003 - val_accuracy: 0.8554
# Epoch 19/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3630 - accuracy: 0.8679 - val_loss: 0.3992 - val_accuracy: 0.8559
# Epoch 20/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3612 - accuracy: 0.8684 - val_loss: 0.3993 - val_accuracy: 0.8564

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the `plot_learning_acc_and_loss` function because we will reuse it in the next steps.

# %%
def plot_learning_acc_and_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_acc_and_loss(history)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8521
# [0.40926671028137207, 0.8521052598953247]

# %% [markdown]
# [TO COMPLETE] Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in this cell.

# %% [markdown]
# <h2><mark><b> Answer:</b></mark></h2>
# In a machine learning problem, we are trying to reach a reasonable estimate for parameters in our model to have acceptable accuracy and loss. In addition, it should be noted that the hyper-parameter in our learning algorithm greatly impacts the results and needs to be given as an input to the machine learning problem. The hyper-parameter, like learning rate, optimizer method, batch size, Etc., needs to be tuned in machine learning. Therefore, at first, for evaluating the model's performance and tuning the hyper-parameter, we split the dataset into train, validation, and test set. We train our model by training data set and find the optimal value for the hyper-parameter by running the trained model on the validation set. Repeat these procedures until we reach an optimum hyper-parameter, which gives us a good result in machine learning problems and does not waste computational power. We run our final model on the test dataset to ensure that the accuracy acquired in the train and validation step is also valid for new data. In the previous step, we should not use the test set because it must be like new and unseen data to have an accurate evaluation of our machine learning model, and we did not consider it before for model building. Since using the test set for the accuracy checking step in machine learning, and when we want to have a correct sense of the accuracy of our model for new input, using the test set may not work for us. Most of the time, it does not give use a correct answer.

# %% [markdown]
# ## [TO COMPLETE] Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..
#
# [TO COMPLETE] In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %%
model = keras.models.Sequential()
#[TO COMPLETE] modify the previuos model in order to obtain a new model that overfits the training data
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=40,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4866 - accuracy: 0.8233 - val_loss: 0.4206 - val_accuracy: 0.8500
# Epoch 2/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4035 - accuracy: 0.8535 - val_loss: 0.4124 - val_accuracy: 0.8511
# Epoch 3/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3859 - accuracy: 0.8591 - val_loss: 0.4012 - val_accuracy: 0.8547
# Epoch 4/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3714 - accuracy: 0.8632 - val_loss: 0.3964 - val_accuracy: 0.8558
# Epoch 5/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3604 - accuracy: 0.8673 - val_loss: 0.3954 - val_accuracy: 0.8569
# Epoch 6/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3505 - accuracy: 0.8711 - val_loss: 0.3978 - val_accuracy: 0.8561
# Epoch 7/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3422 - accuracy: 0.8738 - val_loss: 0.4051 - val_accuracy: 0.8543
# Epoch 8/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3351 - accuracy: 0.8761 - val_loss: 0.3987 - val_accuracy: 0.8579
# Epoch 9/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3285 - accuracy: 0.8795 - val_loss: 0.4054 - val_accuracy: 0.8537
# Epoch 10/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3228 - accuracy: 0.8806 - val_loss: 0.4106 - val_accuracy: 0.8533
# Epoch 11/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3174 - accuracy: 0.8832 - val_loss: 0.4093 - val_accuracy: 0.8558
# Epoch 12/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3122 - accuracy: 0.8850 - val_loss: 0.4134 - val_accuracy: 0.8565
# Epoch 13/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3075 - accuracy: 0.8866 - val_loss: 0.4161 - val_accuracy: 0.8543
# Epoch 14/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3033 - accuracy: 0.8883 - val_loss: 0.4260 - val_accuracy: 0.8539
# Epoch 15/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2996 - accuracy: 0.8899 - val_loss: 0.4229 - val_accuracy: 0.8542
# Epoch 16/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2959 - accuracy: 0.8908 - val_loss: 0.4294 - val_accuracy: 0.8514
# Epoch 17/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2925 - accuracy: 0.8918 - val_loss: 0.4341 - val_accuracy: 0.8512
# Epoch 18/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2891 - accuracy: 0.8934 - val_loss: 0.4351 - val_accuracy: 0.8530
# Epoch 19/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2865 - accuracy: 0.8949 - val_loss: 0.4369 - val_accuracy: 0.8503
# Epoch 20/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2835 - accuracy: 0.8951 - val_loss: 0.4449 - val_accuracy: 0.8464
# Epoch 21/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2816 - accuracy: 0.8952 - val_loss: 0.4458 - val_accuracy: 0.8491
# Epoch 22/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2784 - accuracy: 0.8973 - val_loss: 0.4521 - val_accuracy: 0.8460
# Epoch 23/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2755 - accuracy: 0.8985 - val_loss: 0.4550 - val_accuracy: 0.8480
# Epoch 24/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2737 - accuracy: 0.8995 - val_loss: 0.4577 - val_accuracy: 0.8478
# Epoch 25/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2715 - accuracy: 0.9001 - val_loss: 0.4639 - val_accuracy: 0.8463
# Epoch 26/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2698 - accuracy: 0.9002 - val_loss: 0.4675 - val_accuracy: 0.8428
# Epoch 27/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2673 - accuracy: 0.9013 - val_loss: 0.4700 - val_accuracy: 0.8479
# Epoch 28/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2657 - accuracy: 0.9026 - val_loss: 0.4723 - val_accuracy: 0.8457
# Epoch 29/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2639 - accuracy: 0.9030 - val_loss: 0.4702 - val_accuracy: 0.8465
# Epoch 30/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2621 - accuracy: 0.9036 - val_loss: 0.4772 - val_accuracy: 0.8452
# Epoch 31/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2600 - accuracy: 0.9042 - val_loss: 0.4848 - val_accuracy: 0.8465
# Epoch 32/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2590 - accuracy: 0.9045 - val_loss: 0.4859 - val_accuracy: 0.8412
# Epoch 33/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2568 - accuracy: 0.9062 - val_loss: 0.4932 - val_accuracy: 0.8422
# Epoch 34/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2560 - accuracy: 0.9062 - val_loss: 0.4951 - val_accuracy: 0.8444
# Epoch 35/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2544 - accuracy: 0.9064 - val_loss: 0.4924 - val_accuracy: 0.8403
# Epoch 36/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2533 - accuracy: 0.9069 - val_loss: 0.5008 - val_accuracy: 0.8406
# Epoch 37/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2516 - accuracy: 0.9079 - val_loss: 0.5074 - val_accuracy: 0.8383
# Epoch 38/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2503 - accuracy: 0.9085 - val_loss: 0.5110 - val_accuracy: 0.8413
# Epoch 39/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2493 - accuracy: 0.9085 - val_loss: 0.5157 - val_accuracy: 0.8430
# Epoch 40/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2478 - accuracy: 0.9092 - val_loss: 0.5197 - val_accuracy: 0.8425
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.5290 - accuracy: 0.8367
# [0.5289778113365173, 0.836710512638092]

# %% [markdown]
# Define the `plot_learning_curves` function that plots only the losses (not the accuracy).

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.epoch,history.history['loss'], label='train loss')
    plt.plot(history.epoch,history.history['val_loss'], label='valid loss')
    plt.legend()
    plt.title('loss')
    plt.grid(True)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### [TO COMPLETE] L1 norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow to remove the overfitting effect.

# %%
#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfroms the L1-norm regularization

#[TO COMPLETE] copy the model that you previously defined that overfits the 
#training data, and add the L1-norm regularization. Use a proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1 

#In general, a layer that exploits L1-norm regularization is defined as follows:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE], kernel_regularizer=tf.keras.regularizers.l1([TO COMPLETE]))) 

model = keras.models.Sequential()
#[TO COMPLETE]
#[TO COMPLETE] modify the previuos model in order to obtain a new model that overfits the training data
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.001)))
model.add(keras.layers.Dense(16, activation="relu",kernel_regularizer=tf.keras.regularizers.l1(0.001)))
model.add(keras.layers.Dense(4, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=40,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/40
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.7642 - accuracy: 0.8119 - val_loss: 0.6740 - val_accuracy: 0.8349
# Epoch 2/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.6443 - accuracy: 0.8395 - val_loss: 0.6307 - val_accuracy: 0.8417
# Epoch 3/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.6139 - accuracy: 0.8426 - val_loss: 0.6088 - val_accuracy: 0.8415
# Epoch 4/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5897 - accuracy: 0.8435 - val_loss: 0.5994 - val_accuracy: 0.8357
# Epoch 5/40
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5785 - accuracy: 0.8432 - val_loss: 0.5817 - val_accuracy: 0.8398
# Epoch 6/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5737 - accuracy: 0.8432 - val_loss: 0.5798 - val_accuracy: 0.8386
# Epoch 7/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5704 - accuracy: 0.8440 - val_loss: 0.5877 - val_accuracy: 0.8378
# Epoch 8/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5684 - accuracy: 0.8423 - val_loss: 0.5734 - val_accuracy: 0.8440
# Epoch 9/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5649 - accuracy: 0.8440 - val_loss: 0.5765 - val_accuracy: 0.8375
# Epoch 10/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5629 - accuracy: 0.8432 - val_loss: 0.5746 - val_accuracy: 0.8397
# Epoch 11/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5604 - accuracy: 0.8431 - val_loss: 0.5652 - val_accuracy: 0.8388
# Epoch 12/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5578 - accuracy: 0.8436 - val_loss: 0.5617 - val_accuracy: 0.8407
# Epoch 13/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5565 - accuracy: 0.8431 - val_loss: 0.5540 - val_accuracy: 0.8422
# Epoch 14/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5531 - accuracy: 0.8443 - val_loss: 0.5628 - val_accuracy: 0.8390
# Epoch 15/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5520 - accuracy: 0.8427 - val_loss: 0.5516 - val_accuracy: 0.8412
# Epoch 16/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5496 - accuracy: 0.8425 - val_loss: 0.5550 - val_accuracy: 0.8389
# Epoch 17/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5479 - accuracy: 0.8432 - val_loss: 0.5508 - val_accuracy: 0.8426
# Epoch 18/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5470 - accuracy: 0.8430 - val_loss: 0.5497 - val_accuracy: 0.8399
# Epoch 19/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5453 - accuracy: 0.8425 - val_loss: 0.5490 - val_accuracy: 0.8417
# Epoch 20/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5429 - accuracy: 0.8431 - val_loss: 0.5554 - val_accuracy: 0.8396
# Epoch 21/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5427 - accuracy: 0.8426 - val_loss: 0.5504 - val_accuracy: 0.8395
# Epoch 22/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5427 - accuracy: 0.8439 - val_loss: 0.5524 - val_accuracy: 0.8378
# Epoch 23/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5411 - accuracy: 0.8436 - val_loss: 0.5463 - val_accuracy: 0.8411
# Epoch 24/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5413 - accuracy: 0.8426 - val_loss: 0.5463 - val_accuracy: 0.8410
# Epoch 25/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5415 - accuracy: 0.8437 - val_loss: 0.5454 - val_accuracy: 0.8418
# Epoch 26/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5409 - accuracy: 0.8420 - val_loss: 0.5526 - val_accuracy: 0.8397
# Epoch 27/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5411 - accuracy: 0.8438 - val_loss: 0.5512 - val_accuracy: 0.8378
# Epoch 28/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5413 - accuracy: 0.8427 - val_loss: 0.5471 - val_accuracy: 0.8391
# Epoch 29/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5409 - accuracy: 0.8432 - val_loss: 0.5430 - val_accuracy: 0.8418
# Epoch 30/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5396 - accuracy: 0.8431 - val_loss: 0.5489 - val_accuracy: 0.8422
# Epoch 31/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5408 - accuracy: 0.8431 - val_loss: 0.5558 - val_accuracy: 0.8414
# Epoch 32/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5400 - accuracy: 0.8434 - val_loss: 0.5491 - val_accuracy: 0.8381
# Epoch 33/40
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5397 - accuracy: 0.8428 - val_loss: 0.5463 - val_accuracy: 0.8423
# Epoch 34/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5391 - accuracy: 0.8434 - val_loss: 0.5493 - val_accuracy: 0.8432
# Epoch 35/40
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5401 - accuracy: 0.8428 - val_loss: 0.5475 - val_accuracy: 0.8397
# Epoch 36/40
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5391 - accuracy: 0.8431 - val_loss: 0.5499 - val_accuracy: 0.8402
# Epoch 37/40
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5390 - accuracy: 0.8429 - val_loss: 0.5575 - val_accuracy: 0.8371
# Epoch 38/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5384 - accuracy: 0.8431 - val_loss: 0.5401 - val_accuracy: 0.8447
# Epoch 39/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5380 - accuracy: 0.8434 - val_loss: 0.5458 - val_accuracy: 0.8413
# Epoch 40/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.5383 - accuracy: 0.8432 - val_loss: 0.5430 - val_accuracy: 0.8448
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.8401

# %% [markdown]
# ### [TO COMPLETE] L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainig data, and add the L2-norm regularization. Use proper values for the
#alpha hyper-parameters, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1

#In general, a layer that exploits L2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE],kernel_regularizer=tf.keras.regularizers.l2([TO COMPLETE]))) 

model = keras.models.Sequential()
#[TO COMPLETE]
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(0.005)))
model.add(keras.layers.Dense(16, activation="relu",kernel_regularizer=tf.keras.regularizers.l2(0.005)))
model.add(keras.layers.Dense(4, activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs
40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4810 - accuracy: 0.8459 - val_loss: 0.4868 - val_accuracy: 0.8456
# Epoch 29/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4811 - accuracy: 0.8465 - val_loss: 0.4816 - val_accuracy: 0.8470
# Epoch 30/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4797 - accuracy: 0.8466 - val_loss: 0.4894 - val_accuracy: 0.8443
# Epoch 31/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4803 - accuracy: 0.8461 - val_loss: 0.4963 - val_accuracy: 0.8413
# Epoch 32/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4803 - accuracy: 0.8455 - val_loss: 0.4873 - val_accuracy: 0.8428
# Epoch 33/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4795 - accuracy: 0.8465 - val_loss: 0.4869 - val_accuracy: 0.8454
# Epoch 34/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4787 - accuracy: 0.8457 - val_loss: 0.4907 - val_accuracy: 0.8447
# Epoch 35/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4803 - accuracy: 0.8459 - val_loss: 0.4902 - val_accuracy: 0.8423
# Epoch 36/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4787 - accuracy: 0.8460 - val_loss: 0.4877 - val_accuracy: 0.8462
# Epoch 37/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4790 - accuracy: 0.8464 - val_loss: 0.5020 - val_accuracy: 0.8386
# Epoch 38/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4788 - accuracy: 0.8458 - val_loss: 0.4798 - val_accuracy: 0.8465
# Epoch 39/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4780 - accuracy: 0.8462 - val_loss: 0.4837 - val_accuracy: 0.8435
# Epoch 40/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4781 - accuracy: 0.8462 - val_loss: 0.4840 - val_accuracy: 0.8477
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4916 - accuracy: 0.8411

# %% [markdown]
# ###[TO COMPLETE] Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (`patience` hyper-parameter), it stops the training phase.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainnig data
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the early stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=2),#[TO COMPLETE] play with patience and find the value that prevents the model from overfitting.


    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train, y_train, epochs=40,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/40
# 3375/3375 [==============================] - 15s 4ms/step - loss: 0.4800 - accuracy: 0.8246 - val_loss: 0.4144 - val_accuracy: 0.8524
# Epoch 2/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3957 - accuracy: 0.8555 - val_loss: 0.4064 - val_accuracy: 0.8509
# Epoch 3/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3779 - accuracy: 0.8613 - val_loss: 0.3993 - val_accuracy: 0.8549
# Epoch 4/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3648 - accuracy: 0.8658 - val_loss: 0.3933 - val_accuracy: 0.8569
# Epoch 5/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3537 - accuracy: 0.8704 - val_loss: 0.3934 - val_accuracy: 0.8586
# Epoch 6/40
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3437 - accuracy: 0.8735 - val_loss: 0.3947 - val_accuracy: 0.8577
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4029 - accuracy: 0.8518

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(4, activation="softmax")
                                     ])
    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train, y_train,
                        validation_data=(X_valid, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
    print("evaluation on test set")
    model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.8177 - accuracy: 0.7206 - val_loss: 0.5070 - val_accuracy: 0.8323
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4561 - accuracy: 0.8445 - val_loss: 0.4455 - val_accuracy: 0.8472
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4207 - accuracy: 0.8539 - val_loss: 0.4321 - val_accuracy: 0.8507
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4073 - accuracy: 0.8573 - val_loss: 0.4242 - val_accuracy: 0.8518
# Epoch 5/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3996 - accuracy: 0.8592 - val_loss: 0.4206 - val_accuracy: 0.8509
# Epoch 6/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3942 - accuracy: 0.8602 - val_loss: 0.4175 - val_accuracy: 0.8525
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3898 - accuracy: 0.8616 - val_loss: 0.4153 - val_accuracy: 0.8528
# Epoch 8/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3860 - accuracy: 0.8628 - val_loss: 0.4137 - val_accuracy: 0.8534
# Epoch 9/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3825 - accuracy: 0.8633 - val_loss: 0.4112 - val_accuracy: 0.8539
# Epoch 10/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3793 - accuracy: 0.8642 - val_loss: 0.4104 - val_accuracy: 0.8541
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4198 - accuracy: 0.8463
# Epoch 1/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4616 - accuracy: 0.8326 - val_loss: 0.4389 - val_accuracy: 0.8408
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4096 - accuracy: 0.8520 - val_loss: 0.4205 - val_accuracy: 0.8493
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3907 - accuracy: 0.8589 - val_loss: 0.4100 - val_accuracy: 0.8533
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3756 - accuracy: 0.8632 - val_loss: 0.4203 - val_accuracy: 0.8509
# Epoch 5/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3633 - accuracy: 0.8685 - val_loss: 0.4203 - val_accuracy: 0.8481
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4327 - accuracy: 0.8442
# Epoch 1/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.7453 - accuracy: 0.7387 - val_loss: 0.7061 - val_accuracy: 0.7783
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.7582 - accuracy: 0.6606 - val_loss: 0.7437 - val_accuracy: 0.6527
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.7820 - accuracy: 0.6409 - val_loss: 0.8462 - val_accuracy: 0.6571
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.8462 - accuracy: 0.6496

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_acc_and_loss(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# ### [TO COMPLETE] GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`.

# %% [markdown]
# Let's Create a `build_model()` function that takes two arguments, `n_neurons` and `learning_rate`, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time requirements of the process we will consider only these two hyper-paramters.
#
# [TO COMPLETE] in the following code cell define the `build_model` function.

# %%
def build_model(n_units=30, learning_rate=1e-3):
    # The function has to build a model similar to the ones we used in previuous execises:
    #- a input layer 
    #- one or two Dense layers composed of n_units and that exploit Relu activation function 
    #- the output layer that uses the sigmoid activation function
    # Then, the model has to be compiled.
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(4, activation="softmax")
                                    #[TO COMPLETE]
                                     ])
    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
    # [TO COMPLETE] Then, the model has to be compiled.
    
    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [10,16,22],# [TO COMPLETE] insert a list that contains few (2 or 3) reasonable value
    "learning_rate": [1e-4, 1e-2, 1e-1] #[TO COMPLETE] insert a list that contains few (2 or 3) reasonable values
    #Check how the time required to perform GRID search increases when increasing the number of values for each hyper-parameter.
}

# %% [markdown]
# Use a `sklearn.model_selection.GridSearchCV` to search the hyperparameter space of your `KerasRegressor`

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train.numpy(), y_train.numpy(), epochs=10,#The number of epochs can be modified (check what happens by increasing it)
                validation_data=(X_valid.numpy(), y_valid.numpy()))
# Out:
# Epoch 1/10
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1
# Epoch 8/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.7676 - accuracy: 0.7622 - val_loss: 0.7486 - val_accuracy: 0.7890
# Epoch 9/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.7922 - accuracy: 0.7603 - val_loss: 0.8029 - val_accuracy: 0.7592
# Epoch 10/10
# 2700/2700 [==============================] - 8s 3ms/step - loss: 0.8004 - accuracy: 0.7211 - val_loss: 0.8454 - val_accuracy: 0.7247
# 675/675 [==============================] - 1s 2ms/step - loss: 0.8346 - accuracy: 0.7263
# Epoch 1/10
# 2700/2700 [==============================] - 8s 3ms/step - loss: 0.6683 - accuracy: 0.7723 - val_loss: 0.6102 - val_accuracy: 0.7932
# Epoch 2/10
# 2700/2700 [==============================] - 8s 3ms/step - loss: 0.6395 - accuracy: 0.7862 - val_loss: 0.6899 - val_accuracy: 0.7952
# Epoch 3/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.6355 - accuracy: 0.7776 - val_loss: 0.6173 - val_accuracy: 0.7900
# Epoch 4/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.6301 - accuracy: 0.7803 - val_loss: 0.6719 - val_accuracy: 0.7620
# Epoch 5/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.7651 - accuracy: 0.7083 - val_loss: 0.8896 - val_accuracy: 0.6653
# Epoch 6/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.7730 - accuracy: 0.7352 - val_loss: 0.7793 - val_accuracy: 0.7764
# Epoch 7/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.7707 - accuracy: 0.7303 - val_loss: 0.7344 - val_accuracy: 0.6478
# Epoch 8/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.7634 - accuracy: 0.7336 - val_loss: 0.9185 - val_accuracy: 0.6062
# Epoch 9/10
# 2700/2700 [==============================] - 7s 3ms/step - loss: 0.9105 - accuracy: 0.6093 - val_loss: 0.8976 - val_accuracy: 0.6166
# Epoch 10/10
# 2700/2700 [==============================] - 8s 3ms/step - loss: 0.9025 - accuracy: 0.6088 - val_loss: 0.9289 - val_accuracy: 0.6086
# 675/675 [==============================] - 1s 2ms/step - loss: 0.9307 - accuracy: 0.6149
# Epoch 1/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.7556 - accuracy: 0.7246 - val_loss: 0.4747 - val_accuracy: 0.8403
# Epoch 2/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.4381 - accuracy: 0.8480 - val_loss: 0.4345 - val_accuracy: 0.8514
# Epoch 3/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.4119 - accuracy: 0.8558 - val_loss: 0.4250 - val_accuracy: 0.8516
# Epoch 4/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.4011 - accuracy: 0.8586 - val_loss: 0.4184 - val_accuracy: 0.8523
# Epoch 5/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3946 - accuracy: 0.8598 - val_loss: 0.4158 - val_accuracy: 0.8534
# Epoch 6/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3896 - accuracy: 0.8604 - val_loss: 0.4129 - val_accuracy: 0.8538
# Epoch 7/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3854 - accuracy: 0.8623 - val_loss: 0.4102 - val_accuracy: 0.8544
# Epoch 8/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3817 - accuracy: 0.8629 - val_loss: 0.4088 - val_accuracy: 0.8550
# Epoch 9/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3782 - accuracy: 0.8639 - val_loss: 0.4062 - val_accuracy: 0.8547
# Epoch 10/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3751 - accuracy: 0.8643 - val_loss: 0.4053 - val_accuracy: 0.8540
# GridSearchCV(estimator=<keras.wrappers.scikit_learn.KerasRegressor object at 0x7f7472abe210>,
#              param_grid={'learning_rate': [0.0001, 0.01, 0.1],
#                          'n_units': [10, 16, 22]})

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test, y_test)
# Out:
# {'learning_rate': 0.0001, 'n_units': 22}
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4137 - accuracy: 0.8508
# [0.4137016534805298, 0.850789487361908]
